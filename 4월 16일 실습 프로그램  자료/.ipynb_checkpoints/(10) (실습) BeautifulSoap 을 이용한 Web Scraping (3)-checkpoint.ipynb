# %% [markdown]
# <span style="color:blue">
#
# ## ■ "Daum" site에서 News Data를 수집한 후 worldcloud 그리기
#
# </span>

# %%
## 기본
import numpy as np                    # numpy 패키지 가져오기
import pandas as pd                   # pandas 패키지 가져오기
import matplotlib.pyplot as plt       # 시각화 패키지 가져오기

## Text 데이터 처리
from konlpy.tag import Okt
from konlpy.tag import Kkma
from konlpy.tag import Komoran
from konlpy.tag import Hannanum

from collections import Counter
from wordcloud import WordCloud

from bs4 import BeautifulSoup
import requests

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## (1) 해당 사이트 탐색 단계
#
# ###  ■ Daum 검색창에서 '인공지능'  입력 후 뉴스 페이지로 이동 - 해당 url 을 복사해서 url 변수에  insert

# %%
url ='https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5'

req = requests.get(url)    # 해당 페이지를 가져옴

page = BeautifulSoup(req.text , 'html.parser')

print(page)
# Out:
# <!DOCTYPE doctype html>
#
# <html class="unix unknown " lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="인공지능 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=news&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" property="og:url"/>
# <meta content="Daum 검색에서 인공지능에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>인공지능 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_common.0216035623.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2020/p_component.0805105943.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_collection.0331015031.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_collection2.0216035623.css" rel="stylesheet" type="text/css"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2021/p_coll_tab.0216032523.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var SF, C, T;
# var uk = "YIefUjJ-TfI-VVlvYTpAEAAAAKc";
# var mk = "YIefUjJ-TfI-VVlvYTpAEAAAAKc";
# var ud = "";
# var uuid = "";
# var adid = "";
# var adid_enabled = "N";
# var viewio = "i";
# var viewsite = "";
# var ServerTime = "20210427142122";
# var EnQuery = "%C0%CE%B0%F8%C1%F6%B4%C9";
# var utf8Query = "%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5";
# var topQuery = "인공지능";
# var backQuery = "%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5";
# var login_yn = "N";
# var encodeType = "2";
# var refCode = "";
# var bucketType = "";
# var name_check = "0";
# var mobileDevice = "N";
# var param_w="news";
# var param_da = "NTB";
# var paramCfg = "";
# var param_cnucc = "";
# var tpl_cfg = "";
# var cnucc = "";
# var usrIp = "121.141.76.147";
# var isDetailTab = "N";
# var width_over_620 = "N";
#
# var isReleaseMode = "";
#
# var KAKAO_ACCOUNT_ID_CONNECTED = "N";
#
# var displayInfo = {"SER":[{"code":"TOG","doc_count":0},{"code":"NNS","doc_count":10}],"SGR":[{"code":"1MV","doc_count":0},{"code":"NSJ","doc_count":0},{"code":"DCC","doc_count":0},{"code":"EOA","doc_count":0},{"code":"MBK","doc_count":0},{"code":"DRU","doc_count":0}],"SUI":[]}
# ;
# var slCallType = "sync";
# var pageLoadedTime = 0;
# var startTime = new Date().getTime();
# var sugLocCode = "";
# var searchLog = {
# uc: 0,
# clickCount: 0,
# dl: ""
# };
# var SEARCHLOGDOMAIN = "//sl.search.daum.net";
#
# var CNUCC_URL = "//harm.search.daum.net/api/harmRegister";
# </script>
# <script id="answer-korea-weather-template" type="text/html">
# <span class="weather_comp">
# <span class="txt_exact ico_suggest" data-bind="css: icon40">
# <span class="tit" data-bind="text: areaname"></span>
# <span class="cont"><span class="txt_cont" data-bind="text: wtext5s"></span> <span class="txt_num1 ico_suggest2 ico_celsius" data-bind="text: temp"></span><span class="txt_unit">℃</span></span>
# </span>
# <span class="txt_time" data-bind="text: (announce + ' 기준') "></span>
# </span>
# </script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/polyfill/p/polyfill.p.common.20200707150840.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/vendor/p/common/vendor.p.common.20200309132140.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/log/p_log.min.20210201172233.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/common/module.p.common.20210217134528.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/search/module.p.search.20210309181329.min.js" type="text/javascript"></script>
# <script>
# (function(SF, $, SL) {
# Object.assign(SF, {
# logStaticErrors: {
# isArgonUrl: function(url) {
# return url.indexOf('argon') !== -1;
# },
# extractArgonId: function(url) {
# return url.split('/').pop();
# },
# createFreeLogParams: function(ids) {
# return {
# timg: ids.join(',')
# };
# },
# chunkCall: function (fn, options) {
# var chunk = [];
# var debounced = $.debounce(function() {
# if (chunk.length > 0) {
# fn(chunk);
# chunk = [];
# }
# }, options.timeout);
# return function (arg) {
# chunk.push(arg);
# if (chunk.length >= options.chunkSize) {
# fn(chunk);
# chunk = [];
# }
# debounced();
# };
# },
# init: function() {
# this.subscribe();
# },
# subscribe: function() {
# if (!('addEventListener' in document)) {
# return;
# }
# var sendLog = this.chunkCall(this.sendLog.bind(this), {
# timeout: 1000,
# chunkSize: 50
# });
# var onError = this.onError.bind(this, sendLog);
# this.unsubscribe = function () {
# window.removeEventListener('error', onError);
# };
# window.addEventListener('error', onError, true);
# },
# onError: function (callback, event) {
# var src = event.target.src;
# if (typeof src === 'string' && this.isArgonUrl(src)) {
# callback(this.extractArgonId(src));
# }
# },
# sendLog: function(argonIds) {
# var params = this.createFreeLogParams(argonIds);
# SL.freelog.send(params);
# },
# unsubscribe: $.noop
# }
# });
# })(window.SF || {}, window.jQuery, window.SL || {});
# SF.logStaticErrors.init();
# </script>
# <script type="text/javascript">
# SF.loadModuleList = {
# "amcharts":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/amcharts.20190321202015.min.js",
# "calendar":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/calendar/module.p.calendar.20210312112039.min.js",
# "chart":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/chart.20200602182334.min.js",
# "kakaosdk":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/library/p/kakaosdk.20190321202015.min.js",
# "kakaotv":"//tv.kakao.com/player/script/sdk/player_api.min.js",
# "pagenavigation":"//search1.daumcdn.net/search/statics/common/js/fe/tot-search/module/p/pagenavigation/module.p.pagenavigation.20191016171910.min.js",
# "youtube":"//www.youtube.com/player_api"
# };
# </script>
# <script type="text/javascript">
# (function(SF) {
# Object.assign(SF, {
# phase: 'prod'
# });
# })(window.SF);
# </script>
# <!--[if IE]>
# <script src="//search1.daumcdn.net/search/statics/common/js/g/html5.min.js"></script>
# <![endif]-->
# </meta></head>
# <body class="daum ">
# <script type="text/javascript">
# SL.mkeyLog();
# </script>
# <nav class="d_direct" id="daumIndex">
# <a class="link_direct" href="#daumBody">본문 바로가기</a>
# <a class="link_direct" href="#daumGnb">메뉴 바로가기</a>
# <a class="link_direct" href="#realtimeIssueTitle">실시간이슈 바로가기</a>
# </nav>
# <div id="tooltipContent"></div> <!-- TT -->
# <div id="saq" style="display:none">인공지능</div>
# <article class="daum_wrap daum_tab_news" id="daumWrap">
# <header id="daumHead">
# <div class="inner_header" id="innerHeader">
# <h1>
# <a href="https://www.daum.net/?nil_profile=daum&amp;nil_src=search" id="daumLogo" onclick='smartLog(this, "e=1&amp;dc=MLC", event);' target="_top" title="Daum 메인페이지로 가기">
# <img alt="Daum" height="34" src="//search1.daumcdn.net/search/statics/common/pi/logo/daumlogo_170324.png" width="84"/>
# </a>
# <span class="screen_out" id="daumServiceLogo">검색</span>
# </h1>
# <form class="d_sch" id="daumSearch" method="get" name="search" onsubmit="check_submit(event); return false;">
# <fieldset class="fld_total">
# <legend class="screen_out">검색폼</legend>
# <input id="nil_suggest" name="nil_suggest" type="hidden" value="btn"/>
# <input id="nil_ch" name="nil_ch" type="hidden" value=""/>
# <input name="rtupcoll" type="hidden" value=""/>
# <input name="w" type="hidden" value="news"/>
# <input name="m" type="hidden" value=""/>
# <input id="f" name="f" type="hidden" value=""/>
# <input name="lpp" type="hidden" value=""/>
# <input name="DA" type="hidden" value="SBC"/>
# <input name="sug" type="hidden" value=""/>
# <input name="sq" type="hidden" value=""/>
# <input name="o" type="hidden" value=""/>
# <input name="sugo" type="hidden" value=""/>
# <input name="cluster" type="hidden" value="y"/>
# <div class="box_searchbar">
# <div class="inner_searchbar">
# <input autocomplete="off" class="tf_keyword" id="q" maxlength="255" name="q" spellcheck="false" title="검색어 입력" type="text" value="인공지능"/>
# <button class="img_keyboard btn_key" id="VKIBtn" onclick="SF.virtualKeyboardHandler.call();smartLog(this, 'pg=1&amp;p=1&amp;r=1&amp;rc=1&amp;dc=BFJ&amp;at=func',event);return false;" type="button"><span class="ir_wa">한글입력기</span></button>
# <button class="ico_ksearch btn_ksearch" id="daumBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </div>
# <div class="wrap_suggestBox" id="wrap_suggestBox"><div class="suggestBox box_sub" id="suggestBox"></div></div>
# </fieldset>
# </form>
# <script ?="" type="text/javascript">
# (function() {
# jQuery("#f").val("");
# var searchInp = jQuery("#q");
# var boxSearch = jQuery("#daumSearch .box_searchbar");
# searchInp.on("focus", function() {
# boxSearch.addClass("search_on");
# });
# searchInp.on("blur", function() {
# boxSearch.removeClass("search_on");
# });
# })();
# </script>
# <div id="wrapMinidaum"></div>
# <div class="keyboard_layer" id="VKILayout" style="display:none;"></div>
# <div class="cl_b"></div>
# </div>
# <div id="daumGnb">
# <div class="wrap_gnb">
# <ul class="gnb_search">
# <li class="">
# <a class="tab tab_total" href="?w=tot&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NTB" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'><span class="inner_tab"><span class="txt_tab">통합검색</span></span></a>
# </li>
# <li class="">
# <a class="tab tab_img" href="?w=img&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=2&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">이미지</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_vclip" href="?w=vclip&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=3&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">동영상</span></span>
# </a>
# </li>
# <li class="on">
# <span class="screen_out">선택된 항목</span>
# <a class="tab tab_news" href="?w=news&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;cluster=y&amp;cluster_page=1&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=4&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">뉴스</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_blog" href="?w=blog&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=5&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">블로그</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_cafe" href="?w=cafe&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;ASearchType=1&amp;lpp=10&amp;rlang=0&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=6&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">카페</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_webdoc" href="?w=web&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;lpp=10&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=7&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">웹문서</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_site" href="?w=site&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;lpp=10&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=8&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">사이트</span></span>
# </a>
# </li>
# </ul>
# <div class="more_search">
# <a class="btn_tab" href="javascript:;" id="gnbToggleBtn">
# <span class="txt_btn">더보기/접기</span>
# </a>
# <ul class="list_more">
# <li class="">
# <a class="link_more tab_dic" href="http://dic.daum.net/search.do?q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=9&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=DICZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">어학사전</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_map" href="http://map.daum.net/?from=total&amp;nil_suggest=btn&amp;tab=place&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=10&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=GG1Z&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">지도</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_dic100" href="http://100.daum.net/search/entry?q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=11&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=1DVZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">백과사전</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_shop" href="https://shoppinghow.kakao.com/search/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5/&amp;srchhow=Cexpo" onclick='smartLog(this, "pg=1&amp;r=12&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=SNPZ&amp;dc=NTB&amp;at=more", event);' target="_blank">
# <span class="inner_tab">
# <span class="txt_tab">쇼핑</span>
# <span class="ico_ksearch ico_outlink">새창</span>
# </span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_book" href="?w=book&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=13&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=LB0Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">책</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_music" href="?w=music&amp;m=song&amp;nil_search=btn&amp;DA=NTB&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=14&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=MS2Z&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">멜론뮤직</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_brunch" href="?w=brunch&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=15&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=BRCZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">브런치</span></span>
# </a>
# </li>
# <li class="">
# <a class="link_more tab_kstory" href="?w=kstory&amp;nil_search=btn&amp;DA=NTB&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" onclick='smartLog(this, "pg=1&amp;r=16&amp;p=2&amp;rc=1&amp;e1=NS&amp;e2=KASZ&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">카카오스토리</span></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# _jsSetCookieNonEscape = function(name,value){
# document.cookie = name+"="+value+"; path=/;";
# };
# _jsSetCookieNonEscape("ODT", "IIMZ_VO2Z_NNSZ_BR1Z_CCBZ_WSAZ_IVRZ_");
# _jsSetCookieNonEscape("DDT", "DICZ_GG1Z_1DVZ_SNPZ_LB0Z_MS2Z_BRCZ_KASZ_");
# _jsSetCookieNonEscape("DTQUERY", "%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5" );
#
#
# </script>
# <form method="get" name="cUccForm">
# <input name="kword" type="hidden"/>
# <input name="colid" type="hidden"/>
# <input name="docid" type="hidden"/>
# <input name="backurl" type="hidden"/>
# </form>
# <form method="get" name="urForm">
# <input name="q" type="hidden"/>
# </form>
# <div class="clr"></div>
# <!-- // daumGnb -->
# <div class="skiptonavi" id="searchData" name="searchData"></div>
# <!-- End Header -->
# </header>
# <script id="suggest-footer-template" type="text/html">
# <div>
# <span>
# <div class="fr">
# <a href="http://cs.daum.net/faq/15/14957.html#28978" class="isSuggest" target="_blank" onclick="smartLog(this, 'dc=SUG&p=5&r=1', event);">서제스트란?</a>
# </div>
# </span>
# </div>
# </script>
# <script type="text/javascript">
# var suggestInstance = new suggest.Suggest(document.getElementById('innerHeader'), {
# inputEl: 'q',
# suggestBoxEl: 'suggestBox',
# searchButtonEl: 'daumBtnSearch',
# type: 'DEFAULT',
# autoFocus: 'WRITE',
# suggestLimit: 15,
# recentLimit: 15,
# isReverse: false,
# searchURL: '',
# AnswerAPIServer: 'https://ninstant.search.daum.net/suggest/index.daum',
# enableRecentList: false,
# enableFooter: true
# });
# suggestInstance.on('click-item', function (event) {
# var f = document.search;
# var clickedItemInfo = suggestInstance.getActiveItem();
# var data = clickedItemInfo.data;
# var index = clickedItemInfo.index;
# var type = clickedItemInfo.type;
# f.sug.value = "";
# f.DA.value = "";
# f.nil_suggest.value = "";
# var sgtq = null;
# var sn = null;
# var _ci = function() {
# return document.createElement('input');
# };
# if (clickedItemInfo.type === 'ANSWER') {
# f.sug.value = "totex";
# f.DA.value = "EKS";
# f.nil_suggest.value = "sugsch";
# } else {
# if (data) {
# sgtq = suggestInstance.getUserEnteredQuery();
# sn = index > -1 ? index + 1 : '';
# if (sgtq != null && sgtq != "" ) {
# if (sgtq != null && sgtq != "" && sn != null && sn != "") {
# f.sq.value = sgtq;
# f.o.value = sn;
# f.sugo.value = suggestInstance.getSuggestions().length;
# }
# }
# if (type && type === 'RECENT') {
# f.DA.value = "FFV";
# if (!f.nil_profile) {
# var input = document.createElement('input');
# input.type = 'hidden';
# input.name = 'nil_profile';
# f.appendChild(input);
# } else {
# f.nil_profile.value = '';
# }
# f.nil_profile.value = "reckwd";
# } else {
# f.DA.value = "GIQ";
# f.nil_suggest.value = "sugsch";
# }
# } else {
# f.nil_suggest.value = "btn";
# f.DA.value = "SBC";
# }
# }
# check_submit(event,document.search);
# });
# daum.suggest = window.rudolph || {};
# </script>
# <article id="daumContent">
# <div id="cMain">
# <script type="text/javascript">
# searchLog.dl = '1MV0_TOG0_NSJ0_DCC0_STC1_NNS33_PGD1_RNN1_MNN1_RSN1_EOA1_DRU1_MBK1';	/* ISM DISPLAY_RESULT */
# var smDisCode = "";
# var smClickCode = "";
# var smCateCode = "";
# var totCollCount = "1";
# var sPageLoadedmsTime = 147;
# var requestTime = "1619500882146";
# </script>
# <article id="mArticle">
# <div class="inner_article">
# <span class="screen_out" id="daumBody">검색 본문</span>
# <div class="g_comp" disp-attr="NSJ" style="position: relative;">
# <script type="text/javascript">
# /**
# * 관련검색어 pc용 스크립트
# * 바로가기 니즈 키워드 (기준 CTR 50% 이상) 인 경우 관련검색어 노출을 확대해서(3줄 펼치기 형태) 관련검색어 클릭을 높인다 - 2013.11.5 로직 삭제
# */
# (function (jq) {
# C.netizenColl = C.netizenColl || {};
# C.netizenColl = {
# applyTopBottom: function (position) {
# var NetizenToggle = function (type) {
# this.type = (type) ? type : "";
# this.btnEl = jq("#netizen_more_btn_" + type);
# this.btnTextEl = jq("#netizen_more_btn_" + type + " span.ico_rwd");
# this.listsWrapper = jq("#netizen_lists_" + this.type);
# this.lists = jq("#netizenColl_" + this.type + " .list_keyword span.wsn");
# this.listKeywords = jq("#netizenColl_" + this.type + " .list_keyword span.wsn a.keyword");
# this.tab = this.listsWrapper.data("w");
# this.listFoldClass = (this.tab == "img") ? "type1" : "type2";   /* 이미지는 기본 1줄, 나머지는 기본 2줄 노출 */
# this.listOpenClass = "type3";   /* 쵀대 4줄 노출 */
# };
# NetizenToggle.prototype = {
# init: function () {
# if (this.btnEl.length > 0) {
# this.setListType();
# this.btnEl.unbind("click").bind("click", jq.proxy(this.toggle, this));
# this.listKeywords.unbind("click").bind("click", jq.proxy(this.sendLog, this));
# jq(window).resize(jq.proxy(this.setListType, this));
# }
# },
# setListType: function () {
# var lineCount = this.getLineCount();
# switch (lineCount) {
# case 1:
# this.setBtnStatus("more", "hide");
# this.listsWrapper[0].className = "list_keyword";
# break;
# case 2:
# if (this.tab == "img") {
# if (this.listsWrapper.hasClass("type3")) {
# this.setBtnStatus("fold", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# } else {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# }
# } else {
# this.setBtnStatus("more", "hide");
# this.listsWrapper[0].className = "list_keyword";
# }
# break;
# case 3:
# case 4:
# if (this.tab == "img") {
# if (this.listsWrapper.hasClass("type1") || this.listsWrapper.hasClass("type2")) {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# } else {
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# }
# } else {
# this.setBtnStatus("more", "show");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# }
# break;
# }
# },
# setBtnStatus: function (opt1, opt2) {
# if (opt1 == "more") {
# this.btnEl.removeClass("fold");
# this.btnTextEl.text('더보기');
# } else if (opt1 == "fold") {
# this.btnEl.addClass("fold");
# this.btnTextEl.text('접기');
# }
# if (typeof(opt2) != "undefined") {
# if (opt2 == "hide") {
# jq(this.btnEl).addClass("hide");
# } else if (opt2 == "show") {
# jq(this.btnEl).removeClass("hide");
# }
# }
# },
# toggle: function (e) {
# var lineCount = this.getLineCount();
# var logData = this.btnEl.data("log");
# if (lineCount > 1) {
# if (this.btnEl.length > 0) {
# if (this.btnEl.hasClass("fold")) {
# this.setBtnStatus("more");
# this.listsWrapper[0].className = "list_keyword " + this.listFoldClass;
# smartLog(this.btnEl, logData + "&e=2", e);
# } else {
# this.setBtnStatus("fold");
# this.listsWrapper[0].className = "list_keyword " + this.listOpenClass;
# smartLog(this.btnEl, logData + "&e=1", e);
# }
# }
# }
# },
# getLineCount: function () {
# var list = this.lists[this.lists.length - 1];
# var top = jq(list).position().top;
# var lineHeight = 25;
# var margin = 5;
# /* 한 줄이 25 */
# if (top >= lineHeight * 3 && top >= lineHeight * 3 - margin) {  /* 70~75 */
# return 4;
# } else if (top >= lineHeight * 2 && top >= lineHeight * 2 - margin) { /* 45~50 */
# return 3;
# } else if (top >= lineHeight && top >= lineHeight - margin) {    /* 20~25 */
# return 2;
# } else {    /* ~20 */
# return 1;
# }
# },
# sendLog: function (e) {
# e.stopPropagation();
# var target = function () {
# if (e.target.tagName.toLowerCase() == "span") {
# return e.target.firstChild;
# } else if (e.target.tagName.toLowerCase() == "a") {
# return e.target;
# }
# }();
# var log = jq(target).data("log");
# var extra = {
# "relkwd": {
# "click_query": jq(target).text()
# }
# };
# smartLog(target, log, e, extra);
# }
# };
# var netizenToggle;
# netizenToggle = new NetizenToggle(position);
# netizenToggle.init();
# /* 이미지 탭에서 상단 관련검색어 미들 top 사이즈 체크할 때, 렌더링 타이밍 이슈로 넣어 둠. */
# setTimeout(function () {
# netizenToggle.setListType();
# }, 0);
# },
# applyRight: function () {
# /* ie6, ie7, ipad 가 아니면 */
# if (!((SF.ua.browser.name == "msie" && (SF.ua.browser.version.major == "6" || SF.ua.browser.version.major == "7")) || (SF.ua.browser.name == "ipad"))) {
# this.fixTop();
# }
# var listKeywords = jq("#netizenColl_right .list_keyword a.link_txt");
# listKeywords.unbind("click").bind("click", jq.proxy(this.sendLog, this));
# },
# sendLog: function (e) {
# e.stopPropagation();
# var target = function () {
# if (e.target.tagName.toLowerCase() == "span") {
# return e.target.parentNode;
# } else if (e.target.tagName.toLowerCase() == "a") {
# return e.target;
# }
# }();
# var log = jq(target).data("log");
# var freeLog = {
# "relkwd": {
# "click_query": jq(target).text()
# }
# };
# smartLog(target, log, e, freeLog);
# },
# fixTop: function () {
# var netizenEl = jq("#netizenColl_right")[0];
# if (netizenEl) {
# var bodyHeight = jq("#daumWrap")[0].clientHeight;
# if (viewsite == "0001L") {
# /* SA일경우 */
# var headerHeight = jq("#bingHead")[0].clientHeight;
# var footerHeight = jq("#bingFoot")[0].clientHeight;
# } else {
# var headerHeight = jq("#daumHead")[0].clientHeight;
# var footerHeight = jq("#daumFoot")[0].clientHeight;
# }
# var netizenHeight = netizenEl.clientHeight;
# var netizenTop = jq(netizenEl).position().top;
# var offset = 60;
# /* 우하단 맨위로 버튼으로 인한 오프셋  */
# var prevHeight = 0;
# var browserHeight = 0;
# var checkNetizen = function () {
# var isHorizontalScrollbar = document.documentElement.scrollWidth > document.documentElement.clientWidth;
# var scrollTop = getScrollOffsets().top;
# browserHeight = getWindowSize().height;
# var fixMode = ((scrollTop - headerHeight) >= netizenTop) ? true : false;
# if (isHorizontalScrollbar) {
# fixMode = false;
# }
# if (fixMode) {
# jq(netizenEl).addClass("netizen_fixed");
# if (scrollTop > (bodyHeight - (netizenHeight + footerHeight + offset))) {
# netizenEl.style.top = bodyHeight - (footerHeight + offset + netizenHeight) - scrollTop + "px";
# } else {
# netizenEl.style.top = "-1px";
# }
# } else {
# jq(netizenEl).removeClass("netizen_fixed");
# }
# };
# var getScrollOffsets = function () {
# return {
# 'left': window.pageXOffset || document.documentElement.scrollLeft || document.body.scrollLeft,
# 'top': window.pageYOffset || document.documentElement.scrollTop || document.body.scrollTop
# };
# };
# var getWindowSize = function () {
# var w = (window.innerWidth || document.documentElement.clientWidth || document.body.clientWidth || 1003) - 2,
# h = (window.innerHeight || document.documentElement.clientHeight || document.body.clientHeight || 650) - 2;
# return {"width": w, "height": h};
# };
# checkNetizen();
# jq(window).scroll(checkNetizen);
# jq(window).resize(function () {
# /* 브라우저 리사이즈시에는 높이가 달라졌을때는 클래스 순간 지움. (위치 새로 잡기위해) */
# if (prevHeight == browserHeight) {
# jq(netizenEl).removeClass("netizen_fixed");
# }
# checkNetizen();
# prevHeight = browserHeight;
# });
# }
# }
# };
# /**
# * pc 우측 박스용 말줄임
# */
# C.netizenColl.ellipsis = {
# FRONT_MARGIN: 0,
# ADDITIONAL_MARGIN: 15,
# /**
# 1. 25byte 이상인 서브키가 몇개인지 측정
# 2. 그 글자들과 메인키의 일치비율 측정 => 편집거리 사용.
# 2-1. 키워드와 똑같이 잘라서 편집거리 측정
# 3. 일치비율 >= 0.5 이상이면 중간말줄임, 아니면 기본 말줄임
# */
# draw: function () {
# var _this = this;
# var keyword = decodeURIComponent(utf8Query).replace(/\s/g, "");
# var longKeyword = this.getLongSubkey();
# if (longKeyword.length > 0) {
# var editDistances = jq.map(longKeyword, function (subkey) {
# /* 2-1 단계 */
# var cuttingSubkey = subkey.replace(/\s/g, "").substring(0, keyword.length);
# return _this.getEditDistance(_this.hangulToJaso(keyword), _this.hangulToJaso(cuttingSubkey));
# });
# var sumOfEditDistances = 0;
# jq.each(editDistances, function (index, value) {
# sumOfEditDistances += value;
# });
# var avgOfEditDistances = sumOfEditDistances / editDistances.length;
# var zeroCnt = jq.grep(editDistances, function (dist) {
# return dist <= avgOfEditDistances;
# }).length;
# var sumOfDiffSquare = 0;
# jq.each(editDistances, function (index, dist) {
# sumOfDiffSquare += Math.pow(dist - avgOfEditDistances, 2);
# });
# var matchRatio = zeroCnt / longKeyword.length;
# var variance = sumOfDiffSquare / editDistances.length;
# /* 일치비율이 0.5 이상이거나 0.3 이상이지만 분산이 2보다 작을때는 중간 말줄임 적용(프로그램명 n회 같은 쿼리는 일치비율이 작게 나오기 때문) */
# if (matchRatio >= 0.5 || (matchRatio >= 0.3 && variance < 2)) {
# this.setMiddleEllipsis();
# } else {
# this.setFullSubkey();
# }
# } else {
# this.setFullSubkey();
# }
# },
# /**
# * 25byte 이상인 키워드 몇개인지 측정
# */
# getLongSubkey: function () {
# var _this = this;
# return jq.map(jq("#netizenColl_right .txt_keyword"), function (elem, index) {
# var subkey = jq(elem).attr("data");
# if (_this.getByte(subkey) >= 25) {
# return subkey;
# }
# });
# },
# /**
# * 한글도 2byte로 계산하는 바이트 계산 함수
# */
# getByte: function (s, b, i, c) {
# for (b = i = 0; c = s.charCodeAt(i++); b += c >> 7 ? 2 : 1);
# return b;
# },
# /**
# * 한글 자소 분리
# * brunch B.Util.js 의 hangulToJaso 가져와서 사용.
# */
# hangulToJaso: function (text) {
# var ChoSeong = [0x3131, 0x3132, 0x3134, 0x3137, 0x3138,
# 0x3139, 0x3141, 0x3142, 0x3143, 0x3145, 0x3146, 0x3147, 0x3148,
# 0x3149, 0x314a, 0x314b, 0x314c, 0x314d, 0x314e];
# var JungSeong = [0x314f, 0x3150, 0x3151, 0x3152, 0x3153,
# 0x3154, 0x3155, 0x3156, 0x3157, 0x3158, 0x3159, 0x315a, 0x315b,
# 0x315c, 0x315d, 0x315e, 0x315f, 0x3160, 0x3161, 0x3162, 0x3163];
# var JongSeong = [0x0000, 0x3131, 0x3132, 0x3133, 0x3134,
# 0x3135, 0x3136, 0x3137, 0x3139, 0x313a, 0x313b, 0x313c, 0x313d,
# 0x313e, 0x313f, 0x3140, 0x3141, 0x3142, 0x3144, 0x3145, 0x3146,
# 0x3147, 0x3148, 0x314a, 0x314b, 0x314c, 0x314d, 0x314e];
# var chars = [];
# var v = [];
# for (var i = 0; i < text.length; i++) {
# chars[i] = text.charCodeAt(i);
# if (chars[i] >= 0xAC00 && chars[i] <= 0xD7A3) {
# var i1, i2, i3;
# i3 = chars[i] - 0xAC00;
# i1 = i3 / (21 * 28);
# i3 = i3 % (21 * 28);
# i2 = i3 / 28;
# i3 = i3 % 28;
# v.push(String.fromCharCode(ChoSeong[parseInt(i1)]));
# v.push(String.fromCharCode(JungSeong[parseInt(i2)]));
# if (i3 != 0x0000)
# v.push(String.fromCharCode(JongSeong[parseInt(i3)]));
# }
# else {
# v.push(String.fromCharCode(chars[i]));
# }
# }
# return v.join("");
# },
# /**
# * 편집거리 측정
# */
# getEditDistance: function (a, b) {
# if (a.length === 0) return b.length;
# if (b.length === 0) return a.length;
# var matrix = [];
# /* increment along the first column of each row */
# var i;
# for (i = 0; i <= b.length; i++) {
# matrix[i] = [i];
# }
# /* increment each column in the first row */
# var j;
# for (j = 0; j <= a.length; j++) {
# matrix[0][j] = j;
# }
# /* Fill in the rest of the matrix */
# for (i = 1; i <= b.length; i++) {
# for (j = 1; j <= a.length; j++) {
# if (b.charAt(i - 1) == a.charAt(j - 1)) {
# matrix[i][j] = matrix[i - 1][j - 1];
# } else {
# matrix[i][j] = Math.min(matrix[i - 1][j - 1] + 1, /* substitution */
# Math.min(matrix[i][j - 1] + 1, /* insertion */
# matrix[i - 1][j] + 1)); /* deletion */
# }
# }
# }
# return matrix[b.length][a.length];
# },
# /**
# * 중간 말줄임 적용
# */
# setMiddleEllipsis: function () {
# var width = 0;
# width = (jq("#netizenColl_right .list_keyword").width()) / 2;
# if (width <= 0) {
# this.setFullSubkey();
# return;
# }
# width = width - this.FRONT_MARGIN - this.ADDITIONAL_MARGIN;
# /* width 보다 넓으면 한글자씩 빼기 */
# jq.each(jq("#netizenColl_right .txt_keyword"), function (index, elem) {
# var subkey = jq(elem).attr("data");
# var len = subkey.length;
# jq(elem).text(subkey);
# var mid = len / 2;
# var removeLen = 2;
# var head, tail;
# while (jq(elem).width() > width) {
# head = subkey.substring(0, mid - removeLen / 2);
# tail = subkey.substring(mid + removeLen / 2, len);
# jq(elem).text(head + "..." + tail);
# removeLen++;
# }
# });
# },
# setFullSubkey: function () {
# jq.each(jq("#netizenColl_right .txt_keyword"), function (index, elem) {
# var subkey = jq(elem).attr("data");
# jq(elem).text(subkey);
# });
# }
# };
# jq(document).ready(function () {
# if (jq("#netizenColl_top").length > 0) {
# C.netizenColl.applyTopBottom("top");
# }
# if (jq("#netizenColl_bottom").length > 0) {
# C.netizenColl.applyTopBottom("bottom");
# }
# if (jq("#netizenColl_right").length > 0) {
# C.netizenColl.applyRight();
# C.netizenColl.ellipsis.draw();
# }
# });
# })(jQuery);
# </script>
# <div class="section_related" id="netizenColl_top">
# <div class="list_keyword type2" data-w="news" id="netizen_lists_top">
# <h2 class="tit">
# 관련 <span class="screen_out">검색어</span>
# </h2>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=1&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%A1%9C%EB%B4%87&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%A1%9C%EB%B4%87&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 로봇</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=2&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%9E%80&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%9E%80&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 이란</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=3&amp;p=1&amp;e1=ai&amp;rc=1" href="?w=news&amp;m=&amp;q=ai&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">ai</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=4&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B5%90%EC%9C%A1&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B5%90%EC%9C%A1&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 교육</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=5&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%9C%BB&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%9C%BB&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 뜻</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=6&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B4%80%EB%A0%A8%EC%A3%BC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B4%80%EB%A0%A8%EC%A3%BC&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 관련주</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=7&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%8A%A4%ED%94%BC%EC%BB%A4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%8A%A4%ED%94%BC%EC%BB%A4&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 스피커</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=8&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%94%EB%91%91&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%94%EB%91%91&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 바둑</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=9&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%ED%99%94&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%ED%99%94&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 영화</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=10&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%82%AC%EC%A7%84&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%82%AC%EC%A7%84&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 사진</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=11&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%EC%96%B4%EB%A1%9C&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%EC%96%B4%EB%A1%9C&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 영어로</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=12&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%AF%B8%EC%A7%80&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%AF%B8%EC%A7%80&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 이미지</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=13&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%B1%85&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%B1%85&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 책</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=14&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%A2%85%EB%A5%98&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%A2%85%EB%A5%98&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 종류</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=15&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%9A%8C%EC%82%AC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%9A%8C%EC%82%AC&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 회사</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=16&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9E%A5%EC%A0%90&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9E%A5%EC%A0%90&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 장점</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=17&amp;p=1&amp;e1=AI%20%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;rc=1" href="?w=news&amp;m=&amp;q=AI%20%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">AI 인공지능</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=18&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%84%9C%EB%B9%84%EC%8A%A4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%84%9C%EB%B9%84%EC%8A%A4&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 서비스</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=19&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%95%99%EA%B3%BC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%95%99%EA%B3%BC&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 학과</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=NSJ&amp;pg=1&amp;r=20&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B8%B0%EC%88%A0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B8%B0%EC%88%A0&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=NSJ">인공지능 기술</a></span>
# </div>
# <a class="expender hide" data-log="dc=NSJ&amp;at=func" href="javascript:;" id="netizen_more_btn_top"> <span class="ico_rwd">더보기</span>
# </a>
# </div>
# </div>
# <div class="g_comp" disp-attr="(TAB)news" style="position: relative;">
# <div class="type_fulltext wid_n" id="newsColl"> <div class="coll_tit"> <h2 class="tit">뉴스</h2> <div class="sort_comm"> <span class="btn_sort on">정확도</span> <span class="ico_dot"></span> <a class="btn_sort" href="?w=news&amp;sort=recency&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;cluster=n&amp;DA=STC&amp;dc=STC&amp;pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;at=more&amp;sd=&amp;ed=&amp;period=" onclick='smartLog(this, "dc=STC&amp;pg=1&amp;r=1&amp;p=2&amp;rc=1&amp;at=more", event);'>최신</a> </div> <div class="sub_expander"> <span class="txt_info" id="resultCntArea">1-10 / 약 1,220,000건</span> <div class="wrap_btn"> <a href="?w=news&amp;req=tab&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;cluster=n&amp;viewio=i&amp;repno=0&amp;n=10&amp;p=1&amp;pattern_yn=n&amp;DA=STC" id="linkClusterClose" onclick='smartLog(this, "dc=STC&amp;pg=1&amp;r=1&amp;p=11&amp;rc=1&amp;sd=&amp;ed=", event);'><button class="btn_flex"><span class="inner">관련뉴스 닫기</span></button></a> <button class="btn_flex btn_fold"> <span class="inner">검색옵션<span class="ico_tabopt ico_arr">펼침</span><!-- 펼침/닫기 --></span> </button> </div> </div> </div> <div class="coll_tabopt"> <!-- 기간 옵션 --> <div class="menu_opt"> <a class="tit_menu" data-so-label="period" href="javascript:;"> <span class="txt_data">기간전체</span> <span class="ico_tabopt ico_arr">옵션더보기</span> </a> <div class="layer_opt" data-so-wrapper="period"> <ul class="list_opt"> <li class="on"> <a class="tit_item" data-so-param="period=" href="javascript:;"><span class="txt_data">기간전체</span></a> </li> <li> <a class="tit_item" data-so-param="period=d" href="javascript:;"><span class="txt_data">최근 1일</span></a> </li> <li> <a class="tit_item" data-so-param="period=w" href="javascript:;"><span class="txt_data">최근 1주</span></a> </li> <li> <a class="tit_item" data-so-param="period=m" href="javascript:;"><span class="txt_data">최근 1개월</span></a> </li> <li> <a class="tit_item" data-so-param="period=6m" href="javascript:;"><span class="txt_data">최근 6개월</span></a> </li> <li> <a class="tit_item" data-so-param="period=y" href="javascript:;"><span class="txt_data">최근 1년</span></a> </li> </ul> <div class="box_sub box_date"> <strong class="tit_other">직접입력</strong> <div class="item_date "> <!-- date_open --> <input class="tf_txt" data-so-param="period=u" title="검색기간 시작일" type="text"/> <a class="btn_date" href="javascript:;"> <img alt="Select date" class="ui-datepicker-trigger" src="https://search1.daumcdn.net/search/statics/common/pi/ico/ico_calendar.gif" title="Select date"/> </a> </div> <div class="item_date"> <input class="tf_txt" data-so-param="period=u" title="검색기간 종료일" type="text"/> <a class="btn_date" href="javascript:;"> <img alt="Select date" class="ui-datepicker-trigger" src="https://search1.daumcdn.net/search/statics/common/pi/ico/ico_calendar.gif" title="Select date"/> </a> </div> <button class="btn_confirm" type="submit">적용</button> </div> </div> </div> <!-- // 기간 옵션 --> <!-- 언론사 옵션 --> <div class="menu_opt"> <a class="tit_menu" data-so-label="cpname" href="javascript:;"> <span class="txt_data">언론사전체</span> <span class="ico_tabopt ico_arr">옵션더보기</span> </a> <div class="layer_opt" data-so-wrapper="cpname"> <ul class="list_opt list_media"> <li class="on"> <a class="tit_item" data-so-param="cp=&amp;cpname=" href="javascript:;">언론사 전체</a> </li> <li class=""> <a class="tit_item" href="javascript:;" id="newsCollCpInputWrapper">언론사 직접입력</a> <div class="box_sub "> <div class="item_date"> <input autocomplete="off" class="tf_txt" id="newsCollCpInp" title="언론사입력" type="text" value=""/> </div> <div class="d_sgt simple_suggest" id="newsCollCpSuggest"></div> <button class="btn_confirm" type="submit">적용</button> </div> </li> <li> <a class="tit_item" href="http://media.daum.net/cp" target="_blank">기사제공사 보기 <span class="ico_tabopt ico_target">아웃링크</span></a> </li> </ul> </div> </div> <!-- //언론사 옵션 --> <button class="btn_opt btn_reset" type="button">초기화<span class="ico_tabopt"></span></button> <button class="btn_opt btn_close" type="button"><span class ...
# </div>
# <div class="line"></div><hr/>
# <div disp-attr="DCC">
# <div class="section_related" id="netizenColl_bottom">
# <div class="list_keyword type2" data-w="news" id="netizen_lists_bottom">
# <h2 class="tit">
# 관련 <span class="screen_out">검색어</span>
# </h2>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=1&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%A1%9C%EB%B4%87&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%A1%9C%EB%B4%87&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 로봇</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=2&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%9E%80&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%9E%80&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 이란</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=3&amp;p=1&amp;e1=ai&amp;rc=1" href="?w=news&amp;m=&amp;q=ai&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">ai</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=4&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B5%90%EC%9C%A1&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B5%90%EC%9C%A1&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 교육</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=5&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%9C%BB&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%9C%BB&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 뜻</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=6&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B4%80%EB%A0%A8%EC%A3%BC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B4%80%EB%A0%A8%EC%A3%BC&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 관련주</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=7&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%8A%A4%ED%94%BC%EC%BB%A4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%8A%A4%ED%94%BC%EC%BB%A4&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 스피커</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=8&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%94%EB%91%91&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%94%EB%91%91&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 바둑</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=9&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%ED%99%94&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%ED%99%94&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 영화</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=10&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%82%AC%EC%A7%84&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%82%AC%EC%A7%84&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 사진</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=11&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%EC%96%B4%EB%A1%9C&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%98%81%EC%96%B4%EB%A1%9C&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 영어로</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=12&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%AF%B8%EC%A7%80&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9D%B4%EB%AF%B8%EC%A7%80&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 이미지</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=13&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%B1%85&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%B1%85&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 책</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=14&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%A2%85%EB%A5%98&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%A2%85%EB%A5%98&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 종류</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=15&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%9A%8C%EC%82%AC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%9A%8C%EC%82%AC&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 회사</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=16&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9E%A5%EC%A0%90&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%9E%A5%EC%A0%90&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 장점</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=17&amp;p=1&amp;e1=AI%20%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;rc=1" href="?w=news&amp;m=&amp;q=AI%20%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">AI 인공지능</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=18&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%84%9C%EB%B9%84%EC%8A%A4&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EC%84%9C%EB%B9%84%EC%8A%A4&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 서비스</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=19&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%95%99%EA%B3%BC&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%ED%95%99%EA%B3%BC&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 학과</a></span>
# <span class="wsn"><a class="keyword" data-log="dc=DCC&amp;pg=1&amp;r=20&amp;p=1&amp;e1=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B8%B0%EC%88%A0&amp;rc=1" href="?w=news&amp;m=&amp;q=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EA%B8%B0%EC%88%A0&amp;nzq=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;DA=DCC">인공지능 기술</a></span>
# </div>
# <a class="expender hide" data-log="dc=DCC&amp;at=func" href="javascript:;" id="netizen_more_btn_bottom"> <span class="ico_rwd">더보기</span>
# </a>
# </div>
# </div>
# </div> <!-- // inner_article -->
# </article> <!-- // mArticle -->
# <aside id="mAside">
# <div class="g_comp_s" disp-attr="(TAB)news_RIGHT_APPEND">
# ...
# <div class="g_comp_s" disp-attr="1MV">
# <div class="content_realtime" id="ratThemeColl"> <div class="coll_tit"> <h2 class="tit">영화 종합 검색어</h2> <div class="mg_expander"><span class="f_nb">04.27. 14:21</span></div> </div> <div class="coll_cont"> <div class="wrap_rank"> <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">1</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EB%AF%B8%EB%82%98%EB%A6%AC&amp;scckey=MV||137317" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=1',event);">미나리</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">2</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EB%85%B8%EB%A7%A4%EB%93%9C%EB%9E%9C%EB%93%9C&amp;scckey=MV||143567" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=2',event);">노매드랜드</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">3</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%ED%99%94%EB%85%80&amp;scckey=MV||1487" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=3',event);">화녀</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">4</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EB%82%B4%EC%9D%BC%EC%9D%98%20%EA%B8%B0%EC%96%B5&amp;scckey=MV||131515" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=4',event);">내일의 기억</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">5</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EC%84%9C%EB%B3%B5&amp;scckey=MV||109355" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=5',event);">서복</a></span> </div> </li> </ol> <ol class="list_rank"> <li> <div class="inner_item"> <span class="num_rank">6</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EB%B9%84%EC%99%80%20%EB%8B%B9%EC%8B%A0%EC%9D%98%20%EC%9D%B4%EC%95%BC%EA%B8%B0&amp;scckey=MV||139825" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=6',event);">비와 당신의 이야기</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">7</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EB%8D%94%20%EC%8A%A4%ED%8C%8C%EC%9D%B4&amp;scckey=MV||137958" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=7',event);">더 스파이</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">8</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EB%8D%94%20%ED%8C%8C%EB%8D%94&amp;scckey=MV||137975" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=8',event);">더 파더</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">9</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EC%B0%AC%EC%8B%A4%EC%9D%B4%EB%8A%94%20%EB%B3%B5%EB%8F%84%20%EB%A7%8E%EC%A7%80&amp;scckey=MV||135083" onclick="smartLog(this,'a=RMTO&amp;dc=1MV&amp;pg=1&amp;at=link&amp;rc=10&amp;p=1&amp;r=9',event);">찬실이는 복도 많지</a></span> </div> </li> <li> <div class="inner_item"> <span class="num_rank">10</span> <span class="keyword_rank"> <a class="link_txt" href="?w=tot&amp;rtupcate=38&amp;f=38&amp;rtmaxcoll=1MV,EM1&amp;DA=1MV&amp;q=%EC%8A%AC%EB%A6%AC%ED%94%BC%20%ED%95%A0%EB%A1%9C%EC%9A%B0&amp;scckey=MV||2016" onclick="sma ...
# </div>
# <div class="g_comp_s" disp-attr="TOG">
# <div class="content_commend"> <div class="coll_tit"> <h2 class="tit">같이가치 추천글</h2> </div> <div class="coll_cont"> <ul class="list_major"> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/86573/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-86573&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=1',event);" target="_blank">"암이란 것만으로도 이렇게 힘든데..."</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/86572/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-86572&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=2',event);" target="_blank">치매가 오지 못하도록</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/86118/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-86118&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=3',event);" target="_blank">각자 모두 치료가 필요한 '이 가족'</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/85299/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-85299&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=4',event);" target="_blank">34kg 저체중, 아이의 꿈은...</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/85541/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-85541&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=5',event);" target="_blank">"난 아직 어린데...어른이래요"</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/85612/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-85612&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=6',event);" target="_blank">오늘은 나의 생일입니다</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/85677/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-85677&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=7',event);" target="_blank">"그게 뭐라고, 살아갈 힘이 되더라”</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/86571/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-86571&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=8',event);" target="_blank">"매일 쓰러질까봐 준비해야 돼요"</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/85689/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-85689&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=9',event);" target="_blank">우리는 평균 75세, 초등학생</a> </li> <li> <a class="link_major" href="https://together.kakao.com/fundraisings/86648/story" onclick="smartLog(this,'dc=TOG&amp;d=toget-fundraising_project-86648&amp;rc=10&amp;at=link&amp;pg=1&amp;p=1&amp;r=10',event);" target="_blank">백신 나왔다지만, 여전히...</a> </li> </ul> </div> </div>
# </div>
# <div style="display:block;overflow:hidden;height:0;clear:both;font-size:0;line-height:0;visibility:hidden;">\00f0</div>
# </aside>
# </div>
# <a class="aside_quick" href="javascript:;">맨위로<span class="ico_rwd"></span></a>
# </article>
# <footer id="daumFoot">
# <div class="inner_footer" id="innerFooter">
# <div id="suggestFooter">
# <form class="d_sch" id="daumSearchFoot" method="get" name="search1" onsubmit="check_submit(event); return false;">
# <fieldset class="fld_total">
# <legend class="screen_out">검색폼</legend>
# <input name="nil_ch" type="hidden" value=""/>
# <input name="rtupcoll" type="hidden" value=""/>
# <input name="nil_suggest" type="hidden" value="btn"/>
# <input name="DA" type="hidden" value="MEK"/>
# <input name="w" type="hidden" value="news"/>
# <input name="sq" type="hidden" value=""/>
# <input name="o" type="hidden" value=""/>
# <input name="sugo" type="hidden" value=""/>
# <input name="m" type="hidden" value=""/>
# <div class="box_searchbar">
# <div class="inner_searchbar">
# <input autocomplete="off" class="tf_keyword" id="q1" name="q" onclick="cleanKwd(this);" title="검색어 입력" type="text" value="인공지능"/>
# <button class="ico_ksearch btn_ksearch" id="daumBtnSearch2" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# <div class="wrap_suggestBox"><div class="suggestBox box_sub reverseType" id="suggestBox2"></div></div>
# </div>
# <script type="text/javascript">
# (function(){
# var footerSearchInp = jQuery("#q1"), boxSearchBar = jQuery("#daumFoot .box_searchbar");
# footerSearchInp.on("focus", function() {
# boxSearchBar.addClass("search_on");
# });
# footerSearchInp.on("blur", function() {
# boxSearchBar.removeClass("search_on");
# });
# var footerSuggestInstance = new suggest.Suggest(document.getElementById('suggestFooter'), {
# inputEl: 'q1',
# suggestBoxEl: 'suggestBox2',
# searchButtonEl: 'daumBtnSearch2',
# type: 'DEFAULT',
# autoFocus: 'NORMAL',
# isReverse: true,
# suggestLimit: 15,
# enableFooter: true
# });
# footerSuggestInstance.on('click-item', function (event) {
# var f = document.search1;
# var clickedItemInfo = footerSuggestInstance.getActiveItem();
# var data = clickedItemInfo.data;
# var index = clickedItemInfo.index;
# var type = clickedItemInfo.type;
# var sgtq = null;
# var sn = null;
# f.DA.value = "";
# f.nil_suggest.value = "";
# if (data) {
# sgtq = footerSuggestInstance.getUserEnteredQuery();
# sn = index + 1;
# if (sgtq != null && sgtq != "" ) {
# if (sgtq != null && sgtq != "" && sn != null && sn != "") {
# f.sq.value = sgtq;
# f.o.value = sn;
# f.sugo.value = footerSuggestInstance.getSuggestions().length;
# }
# }
# f.DA.value = "FKB";
# f.nil_suggest.value = "sugsch";
# } else {
# f.nil_suggest.value = "btn";
# f.DA.value = "MEK";
# }
# check_submit(event, document.search1);
# });
# })();
# </script>
# <div class="footer_comm">
# <a class="link_info" href="http://daumsearch.tistory.com" onclick="smartLog(this, 'pg=1&amp;p=10&amp;dc=CCC&amp;r=1', event);" target="_blank">검색블로그</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://register.search.daum.net/" onclick="smartLog(this, 'pg=1&amp;p=9&amp;dc=CCC&amp;r=1', event);" target="_blank">사이트ㆍ지역 등록신청</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://partner.search.daum.net/partner/index.daum" onclick="smartLog(this, 'pg=1&amp;p=12&amp;dc=CCC&amp;r=1', event);" target="_blank">검색제휴</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://business.kakao.com/info/keywordad" onclick="smartLog(this, 'pg=1&amp;p=2&amp;dc=CCC&amp;r=1', event);" target="_blank">키워드광고</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://local.biz.daum.net/" onclick="smartLog(this, 'pg=1&amp;p=3&amp;dc=CCC&amp;r=1', event);" target="_blank">로컬광고</a><span class="txt_bar">|</span>
# <a class="link_info" href="https://business.kakao.com/info/crossmedia" onclick="smartLog(this, 'pg=1&amp;p=8&amp;dc=CCC&amp;r=1', event);" target="_blank">크로스미디어</a><span class="txt_bar">|</span>
# <a class="link_info" href="http://cs.daum.net/faq/15.html" onclick="smartLog(this, 'pg=1&amp;p=6&amp;dc=CCC&amp;r=1', event);" target="_blank">고객센터</a>
# <address class="copyright">   ⓒ <a class="link_daum" href="http://kakaocorp.com" onclick="smartLog(this, 'pg=1&amp;p=11&amp;dc=CCC&amp;r=1', event);" target="_blank">Kakao Corp.</a></address>
# </div>
# </div>
# </footer>
# </article>
# <script type="text/javascript">
# var __MiniDaumObj = null;
# var minidaum_options = null;
# (function() {
# minidaum_options = {
# bgType: "",
# enableLogoutRetun: true,
# disableHotissue: true,
# disableLogo: true,
# disableTracker: true,
# enableShield: false
# };
# })();
# </script>
# <script async="" charset="utf-8" defer="" src="//go.daum.net/minidaum_pc.daum" type="text/javascript"></script>
# <script type="text/javascript">
# SF.CommonModule && SF.CommonModule.init && SF.CommonModule.init();
# </script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# (function() {
# if (typeof TiaraTracker === 'undefined') {
# return;
# }
# var svcdomain = window.viewio === 'i' ? window.param_w + '.search.daum.net' : 'nate.search.daum.net';
# var pageName = window.param_w === 'tot' ? '통합검색' : window.param_w + '탭';
# var search = {
# search_term: window.topQuery,
# search_type:  window.param_da
# };
# TiaraTracker.getInstance()
# .setSvcDomain(svcdomain)
# .setPage(pageName)
# .setSection('검색결과')
# .trackPage('검색결과화면_조회')
# .actionKind("Search")
# .search(search)
# .track();
# })();
# </script>
# <script type="text/javascript">
# window.roosevelt_params_queue = window.roosevelt_params_queue || [];
# window.roosevelt_params_queue.push({
# channel_id: "dk", channel_label: "search", keyword: window.topQuery
# });
# </script>
# <script async="" src="//t1.daumcdn.net/midas/rt/dk_se/roosevelt_dk_se.js" type="text/javascript"></script>
# <script>
# (function(SF) {
# if (SF.compLogger && SF.compLogger.sendAllFromPage) {
# SF.compLogger.sendAllFromPage({
# ref: 'search'
# });
# }
# })(window.SF || {});
# </script>
# <!-- SA 삭제 -->
# <!-- end SA 삭제 -->
# </body>
# </html>

# %% [markdown]
# ### ▶ 검색 데이터의 headline 을 추출한다.
#
# #### -  F12 (검사 모드) 누른 후 해당 소스의 태그 id 혹은 class 를 찾는다.

# %%
titles = page.find_all(attrs='f_link_b')

print(titles)
# Out:
# [<a class="f_link_b" href="http://v.media.daum.net/v/20210427090038622?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26o7fdjZghVm3_Hivx&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16Elf9uX5H6T5xXvQV&amp;e3=0&amp;ext=dsid=26o7fdjZghVm3_Hivx", event, {"cpid": {"value": "16Elf9uX5H6T5xXvQV"}});' target="_blank">단국대, 학생들에게 <b>인공지능</b> 비서 제공</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210427101327037?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26yhzUTyBOuVU6T4j2&amp;pg=1&amp;r=2&amp;p=4&amp;rc=10&amp;e1=16JfL24RCJKYboAM86&amp;e3=0&amp;ext=dsid=26yhzUTyBOuVU6T4j2", event, {"cpid": {"value": "16JfL24RCJKYboAM86"}});' target="_blank">빅데이터 <b>인공지능</b>, 신병 전투복·운동복 만족도 높였다</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210427094356614?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26x4pnCX91CCdvK_DV&amp;pg=1&amp;r=3&amp;p=4&amp;rc=10&amp;e1=16JfL24RCJKYboAM86&amp;e3=0&amp;ext=dsid=26x4pnCX91CCdvK_DV", event, {"cpid": {"value": "16JfL24RCJKYboAM86"}});' target="_blank">인천시, <b>인공지능</b> 덕분에..방역 역할 톡톡</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210426110551422?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26GqBnKjMc5X-svzxb&amp;pg=1&amp;r=4&amp;p=4&amp;rc=10&amp;e1=16PxLkJt1h6kPgSYDm&amp;e3=0&amp;ext=dsid=26GqBnKjMc5X-svzxb", event, {"cpid": {"value": "16PxLkJt1h6kPgSYDm"}});' target="_blank">아이반, 자작곡 '<b>인공지능</b>' 오디오 티저 공개</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210427115510513?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26nDmKMqaXZIfBUqPo&amp;pg=1&amp;r=5&amp;p=4&amp;rc=10&amp;e1=16_-rXIov6CN5sdGtY&amp;e3=0&amp;ext=dsid=26nDmKMqaXZIfBUqPo", event, {"cpid": {"value": "16_-rXIov6CN5sdGtY"}});' target="_blank">'<b>인공지능</b> 투자' 파운트, 적립식 투자자 70% 2030</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210427114604199?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26cHhw6VrfRnWwBWZD&amp;pg=1&amp;r=6&amp;p=4&amp;rc=10&amp;e1=16nzyJHdH5ORpabfqG&amp;e3=0&amp;ext=dsid=26cHhw6VrfRnWwBWZD", event, {"cpid": {"value": "16nzyJHdH5ORpabfqG"}});' target="_blank">삼성전자, <b>인공지능</b> 청소기 '비스포크 제트 봇 AI' 출시</a>, <a class="f_link_b" href="https://cp.news.search.daum.net/p/105594007" onclick='smartLog(this, "dc=NNS&amp;d=262O0vQGvJ1tCLgA39&amp;pg=1&amp;r=7&amp;p=4&amp;rc=10&amp;e1=167tBrDH9BuZpZZ1ih&amp;e3=0&amp;ext=dsid=262O0vQGvJ1tCLgA39", event, {"cpid": {"value": "167tBrDH9BuZpZZ1ih"}});' target="_blank">대전만의 <b>인공지능</b> 교육 문화를 누리다!</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210427105121102?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26wOA27wiOc4FzSa-x&amp;pg=1&amp;r=8&amp;p=4&amp;rc=10&amp;e1=16xPi3xTTvS9eQchSd&amp;e3=0&amp;ext=dsid=26wOA27wiOc4FzSa-x", event, {"cpid": {"value": "16xPi3xTTvS9eQchSd"}});' target="_blank">인천시, <b>인공지능</b>(AI) 도입 코로나19 돌봄전화 서비스</a>, <a class="f_link_b" href="http://v.media.daum.net/v/20210426140609429?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26v0x1ZznHoI2iVgCL&amp;pg=1&amp;r=9&amp;p=4&amp;rc=10&amp;e1=16iL25JCNSvhQN0hEU&amp;e3=0&amp;ext=dsid=26v0x1ZznHoI2iVgCL", event, {"cpid": {"value": "16iL25JCNSvhQN0hEU"}});' target="_blank">호남대학교, <b>인공지능</b> 신기술 릴레이 특강</a>, <a class="f_link_b" href="https://cp.news.search.daum.net/p/105597061" onclick='smartLog(this, "dc=NNS&amp;d=26L4bzw9i4ciD2sBWI&amp;pg=1&amp;r=10&amp;p=4&amp;rc=10&amp;e1=16LCcWbu_th-HHdy13&amp;e3=0&amp;ext=dsid=26L4bzw9i4ciD2sBWI", event, {"cpid": {"value": "16LCcWbu_th-HHdy13"}});' target="_blank">인하대, 인천 최초의 <b>인공지능</b> 특화 연구교육기관 열어</a>]

# %% [markdown]
# ### ▶ 검색된 title의 크기를 확인한다.

# %%
print(len(titles))
# Out:
# 10

# %% [markdown]
# ### ▶ 검색된 title의 각각을 프린트 한다.

# %%
for title in titles :
    print(title.text)
    print()
# Out:
# 단국대, 학생들에게 인공지능 비서 제공
#
# 빅데이터 인공지능, 신병 전투복·운동복 만족도 높였다
#
# 인천시, 인공지능 덕분에..방역 역할 톡톡
#
# 아이반, 자작곡 '인공지능' 오디오 티저 공개
#
# '인공지능 투자' 파운트, 적립식 투자자 70% 2030
#
# 삼성전자, 인공지능 청소기 '비스포크 제트 봇 AI' 출시
#
# 대전만의 인공지능 교육 문화를 누리다!
#
# 인천시, 인공지능(AI) 도입 코로나19 돌봄전화 서비스
#
# 호남대학교, 인공지능 신기술 릴레이 특강
#
# 인하대, 인천 최초의 인공지능 특화 연구교육기관 열어

# %% [markdown]
# ## (2) 본격 스크래핑 단계
#
#
# ### ▶ 첫 페이지부터 원하는 페이지 까지 뉴스 헤드라인울 스크래핑하는 함수 정의

# %%
# 해드라인 검색 및 추출 함수를 정의
# 검색 키워드 & 스타트 페이지 & 검색 마지막 페이지를 parameter(매개변수) 로 받음
# 파이썬은 매개변수가 여러개 인 경우 뒤의 매개 변수부터 디폴트값을 가질 수 있음 

title_list = []

def web_scraping(keyword, end, start = 1):    # 시작 페이지의 default 값은 1 (즉, 첫 페이지 부터 시작) 
    while 1:

        if start > end :    # 스타트 페이지가 마지막 페이지보다 크면 while 문을 빠져 나감 
            break        
        
        url ='https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q={}&p={}'.format(keyword,start)

        req = requests.get(url)    # 해당 페이지를 가져옴

        page = BeautifulSoup(req.text, 'html.parser')

        titles = page.find_all(attrs='f_link_b')     # 헤드라인 기사를 가져옴 
        
        print(titles)       # 추출한 헤드라인을 확인 (10개)

        for one in titles:
            title_list.append(one.text)
            
        start += 1

# %% [markdown]
# ### ▶ 위 함수를 호출

# %%
# 검색어를 입력 받음 


keyword = input('검색어를 입력하세요 : ')
print()

end_page = 10

web_scraping(keyword, end_page)       # 10 페이지 까지 스크래핑을 해온다.
# Out:
# 검색어를 입력하세요 : 인공지능
#
# [<a class="f_link_b" href="http://v.media.daum.net/v/20
# %%
# 수집해온 헤드라인 갯수를 확인 

print(len(title_list))
# Out:
# 100

# %% [markdown]
# ## (3) 데이터 분석 단계
#
#
# ### ▶ 형태소 분석

# %%
# 형태소 분석 - 분석하는데 약간의 시간이 걸림 

kkma = Kkma()

sentences_tag = []

for sentence in title_list:
    word_tag = kkma.pos(sentence)
    sentences_tag.append(word_tag)


print(sentences_tag)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-16-199a3f2c7b07> in <module>
#       1 # 형태소 분석 - 분석하는데 약간의 시간이 걸림
#       2
# ----> 3 kkma = Kkma()
#       4
#       5 sentences_tag = []
#
# ~\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in __init__(self, jvmpath, max_heap_size)
#      93     def __init__(self, jvmpath=None, max_heap_size=1024):
#      94         if not jpype.isJVMStarted():
# ---> 95             jvm.init_jvm(jvmpath, max_heap_size)
#      96
#      97         kkmaJavaPackage = jpype.JPackage('kr.lucypark.kkma')
#
# ~\Anaconda3\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      65                                 '-Dfile.encoding=UTF8',
#      66                                 '-ea', '-Xmx{}m'.format(max_heap_size),
# ---> 67                                 convertStrings=True)
#      68     else:
#      69         raise ValueError("Please specify the JVM path.")
#
# ~\Anaconda3\lib\site-packages\jpype\_core.py in startJVM(*args, **kwargs)
#
# SystemError: java.lang.UnsatisfiedLinkError: Can't load library: C:\Users\user\Anaconda3\lib\site-packages\_jpype.cp37-win_amd64.pyd

# %% [markdown]
# ### ▶ 명사 추출

# %%
# 형태소 분석 후 명사만 추출

noun_list = []

for sentence in sentences_tag:
    for word, tag in sentence:
        if tag in ['@@@']:               # okt = Okt() 인 경우  if tag in ['Noun']:
            noun_list.append(@@@)
            
print(noun_list)

# %% [markdown]
# ### ▶ 두음절 이상 단어만 추출

# %%
# 명사 중에서 두음절 단어만 추출 


print('▶ 전체 명사의 수 = ', len(noun_list))
print() 

noun_list = [word for word in @@@ if len(word) > 1]    # 명사중에서 두음절 이상의 단어  추출


print('▶ 두음절 이상의 명사의 수 = ', len(noun_list))
print() 

print(noun_list[:100])   # 처음부터 나오는 순서대로 100개 단어 출력

# %% [markdown]
# ### ▶ 추출된 단어들의 출현 횟수를 확인

# %%
# 단어의 출현 횟수 카운트

counts = @@@(noun_list)

words = counts.@@@(50)     # 가장 많이 출현한 횟수 순으로 50개 단어만 추출 한 후 word clouding  

print(words)

# %% [markdown]
# ### ▶ 단어 출현 횟수에 근거하여 word cloude 를 생성

# %%
# wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
#                       background_color='white',                   
#                       colormap = 'Accent_r',   
#                       width=800,
#                       height=600)

wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      colormap = 'Accent_r',
                      width=800,
                      height=600)

print(dict(words))

cloud = wordcloud.generate_from_frequencies(@@@)

plt.figure(figsize=(10, 8))

plt.axis('off')   

plt.imshow(cloud)

plt.show()

# %% [markdown]
# ## 수고하셨습니다.  😀
